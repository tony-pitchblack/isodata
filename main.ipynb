# %%
from isodata import isodata_classification
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from help_funcs import img_to_ndarray

# %%
# load and show test image

# img = Image.open('data/input/img/houses_grayscale.jpg')
# imgplot = plt.imshow(img, cmap='gray', vmin=0, vmax=255)
img = Image.open('data/input/img/houses.jpg')
imgplot = plt.imshow(img)

# %%
# clusterize using ISODATA algorithm
houses_data, N, M, depth = img_to_ndarray(img)
K = 2
img_classes = isodata_classification(houses_data,
                                             parameters={'K': K})
# Out:
# ('Isodata(info): Starting algorithm with 2 classes', 2)
# Given 1152000 objects with 1 features
# Chosen initial 2 centers: [[41]
#  [69]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 4>()
#       2 houses_data, N, M, depth = img_to_ndarray(img)
#       3 K = 2
# ----> 4 img_classes = isodata_classification(houses_data,
#       5                                              parameters={'K': K})
#
# File ~\PycharmProjects\isodata\isodata.py:402, in isodata_classification(X, parameters)
#     398 last_centers = centers.copy()
#     400 # assing each of the samples to the closest cluster center
# --> 402 img_class_flat, dists = vq.vq(X, centers) # ВООБЩЕ не понятно, как работает эта строка
#     404 centers, clusters_list = discard_clusters(img_class_flat,
#     405                                           centers, clusters_list)
#     406 centers, clusters_list = update_clusters(X,
#     407                                          img_class_flat,
#     408                                          centers, clusters_list)
#
# File ~\PycharmProjects\isodata\venv\lib\site-packages\scipy\cluster\vq.py:208, in vq(obs, code_book, check_finite)
#     205 c_code_book = code_book.astype(ct, copy=False)
#     207 if np.issubdtype(ct, np.float64) or np.issubdtype(ct, np.float32):
# --> 208     return _vq.vq(c_obs, c_code_book)
#     209 return py_vq(obs, code_book, check_finite=False)
#
# File _vq.pyx:209, in scipy.cluster._vq.vq()
#
# ValueError: observation and code should have same number of dimensions

# %%
# show clusterized image

fig, ax = plt.subplots()
im = ax.imshow(img_classes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 4>()
#       1 # show clusterized image
#       3 fig, ax = plt.subplots()
# ----> 4 im = ax.imshow(img_classes)
#
# NameError: name 'img_classes' is not defined

# %%
# save clusterized image
ax.set_title(f"Satellite house image pixel classes ({K})")
fig.tight_layout()
plt.show()
# fig.savefig(f'data/output/img/houses_out_{K}_classes.jpg', bbox_inches='tight', dpi=500)

img.close()
